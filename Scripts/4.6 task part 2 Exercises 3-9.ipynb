# %%
# Contents: Import libraries and data set, check data set, import 2nd dataset and check, merge 2 sets and check, import result.

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Exercise #3. Importing orders_products_combined df
df_orders_products_combined = pd.read_pickle(r'C:\Users\steph\OneDrive\Documents\May 2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
#Exercise #4.
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    time_of_order  days_since_prior_order  product_id  add_to_cart_order  \
# 0              8                     NaN         196                  1
# 1              8                     NaN       14084                  2
# 2              8                     NaN       12427                  3
# 3              8                     NaN       26088                  4
# 4              8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
vars_list = ['product_id', 'product_name', 'aisle_id', 'department_id', 'prices']

# %%
#Importing products_cleaned2
df_products_cleaned2 = pd.read_csv(r'C:\Users\steph\OneDrive\Documents\May 2022 Instacart Basket Analysis\02 Data\Prepared Data\products_cleaned2.csv', usecols = vars_list)

# %%
df_products_cleaned2.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_products_cleaned2.shape
# Out:
# (49672, 5)

# %%
# Exercise 5 Merging cleaned products and orders and products combined
df_orders_products_merged = df_orders_products_combined.merge(df_products_cleaned2, on = 'product_id')

# %%
# Exercise 6. checking merge flag df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    time_of_order  days_since_prior_order  product_id  add_to_cart_order  \
# 0              8                     NaN         196                  1
# 1              7                    15.0         196                  1
# 2             12                    21.0         196                  1
# 3              7                    29.0         196                  1
# 4             15                    28.0         196                  1
#
#    reordered _merge product_name  aisle_id  department_id  prices
# 0          0   both         Soda        77              7     9.0
# ...

# %%
df_orders_products_merged.to_pickle(r'C:\Users\steph\OneDrive\Documents\May 2022 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')
